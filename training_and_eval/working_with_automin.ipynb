# %% [markdown]
# <a href="https://colab.research.google.com/github/iftwigs/thesis-cnn-dm-automin/blob/main/training_and_eval/working_with_automin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/huggingface/transformers.git
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 72857, done.
# remote: Counting objects: 100% (886/886), done.
# remote: Compressing objects: 100% (507/507), done.
# remote: Total 72857 (delta 506), reused 587 (delta 333), pack-reused 71971
# Receiving objects: 100% (72857/72857), 56.38 MiB | 29.37 MiB/s, done.
# Resolving deltas: 100% (51648/51648), done.

# %%
# !pip install datasets sacremoses sentencepiece sacrebleu bleu rouge rouge_score
# Out:
# Collecting datasets
#   Downloading https://files.pythonhosted.org/packages/46/1a/b9f9b3bfef624686ae81c070f0a6bb635047b17cdb3698c7ad01281e6f9a/datasets-1.6.2-py3-none-any.whl (221kB)
#      |████████████████████████████████| 225kB 6.4MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 8.9MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 18.4MB/s
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/7e/57/0c7ca4e31a126189dab99c19951910bd081dea5bbd25f24b77107750eae7/sacrebleu-1.5.1-py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 8.2MB/s
# Collecting bleu
#   Downloading https://files.pythonhosted.org/packages/ae/df/4fd9bfe6dc240a1760f8e95ca41aa31382e328e31de45145f528dab5c7f8/bleu-0.3.tar.gz
# Collecting rouge
#   Downloading https://files.pythonhosted.org/packages/43/cc/e18e33be20971ff73a056ebdb023476b5a545e744e3fc22acd8c758f1e0d/rouge-1.0.0-py3-none-any.whl
# Collecting rouge_score
#   Downloading https://files.pythonhosted.org/packages/1f/56/a81022436c08b9405a5247b71635394d44fe7e1dbedc4b28c740e09c2840/rouge_score-0.0.4-py2.py3-none-any.whl
# Collecting xxhash
#   Downloading https://files.pythonhosted.org/packages/7d/4f/0a862cad26aa2ed7a7cd87178cbbfa824fc1383e472d63596a0d018374e7/xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243kB)
#      |████████████████████████████████| 245kB 28.7MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.11.1)
# Requirement already satisfied: pyarrow>=1.0.0<4.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.1.5)
# Collecting fsspec
#   Downloading https://files.pythonhosted.org/packages/bc/52/816d1a3a599176057bf29dfacb1f8fadb61d35fbd96cb1bab4aaa7df83c0/fsspec-2021.5.0-py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 29.2MB/s
# Collecting huggingface-hub<0.1.0
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (20.9)
# Requirement already satisfied: tqdm<4.50.0,>=4.27 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.41.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from datasets) (4.0.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.19.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses) (8.0.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses) (1.15.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacremoses) (2019.12.20)
# Collecting portalocker==2.0.0
#   Downloading https://files.pythonhosted.org/packages/89/a6/3814b7107e0788040870e8825eebf214d72166adf656ba7d4bf14759a06a/portalocker-2.0.0-py2.py3-none-any.whl
# Collecting efficiency
#   Downloading https://files.pythonhosted.org/packages/34/c9/ecc9958e1ca22b5e060a2685405e27c44aaf921e53e3318136fff5ed60e2/efficiency-0.5.tar.gz
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from rouge_score) (3.2.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from rouge_score) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets) (3.0.12)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->datasets) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->datasets) (3.7.4.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (from efficiency->bleu) (2.2.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy->efficiency->bleu) (56.1.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy->efficiency->bleu) (1.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->efficiency->bleu) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->efficiency->bleu) (2.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->efficiency->bleu) (0.8.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy->efficiency->bleu) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->efficiency->bleu) (3.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->efficiency->bleu) (7.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->efficiency->bleu) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy->efficiency->bleu) (1.0.0)
# Building wheels for collected packages: bleu, efficiency
#   Building wheel for bleu (setup.py) ... done
#   Created wheel for bleu: filename=bleu-0.3-cp37-none-any.whl size=5802 sha256=36e78b43ac2167991667e42237c15455bc974665b8ff0f50a32513f145de3fed
#   Stored in directory: /root/.cache/pip/wheels/a9/95/e7/cb43a1c509c38fedbee6223963e34a51a94d8991f3b3e1888e
#   Building wheel for efficiency (setup.py) ... done
#   Created wheel for efficiency: filename=efficiency-0.5-cp37-none-any.whl size=20285 sha256=7a80fee23fe8a42b0cee8f873dfd8a0debc24b3227f16424e821f5a21c3f0c2b
#   Stored in directory: /root/.cache/pip/wheels/94/fd/e6/2d34e80768fb2d001fc35b033a48114b1afdb6ea020b4cb2c7
# Successfully built bleu efficiency
# Installing collected packages: xxhash, fsspec, huggingface-hub, datasets, sacremoses, sentencepiece, portalocker, sacrebleu, efficiency, bleu, rouge, rouge-score
# Successfully installed bleu-0.3 datasets-1.6.2 efficiency-0.5 fsspec-2021.5.0 huggingface-hub-0.0.8 portalocker-2.0.0 rouge-1.0.0 rouge-score-0.0.4 sacrebleu-1.5.1 sacremoses-0.0.45 sentencepiece-0.1.95 xxhash-2.0.2

# %%
cd transformers/
# Out:
# /content/transformers

# %%
# !python examples/pytorch/summarization/run_summarization.py \
    --model_name_or_path t5-small \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file /content/drive/MyDrive/automin_processed/train_automin.csv \
    --validation_file /content/drive/MyDrive/automin_processed/val_automin.csv \
    --test_file /content/drive/MyDrive/automin_processed/test_automin.csv \
    --output_dir /content/drive/MyDrive/t5-small-automin-automin \
    --per_device_train_batch_size=4 \
    --per_device_eval_batch_size=4 \
    --num_train_epochs=10 \
    --overwrite_output_dir \
    --predict_with_generate
# Out:
# 2021-05-19 13:54:43.917458: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# You're running a t5 model but didn't provide a source prefix, which is the expected, e.g. with `--source_prefix 'summarize: ' `
# 05/19/2021 13:54:45 - WARNING - __main__ -   Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 05/19/2021 13:54:45 - INFO - __main__ -   Training/evaluation parameters Seq2SeqTrainingArguments(output_dir='/content/drive/MyDrive/t5-small-automin-automin', overwrite_output_dir=True, do_train=True, do_eval=True, do_predict=True, evaluation_strategy=<IntervalStrategy.NO: 'no'>, prediction_loss_only=False, per_device_train_batch_size=4, per_device_eval_batch_size=4, per_gpu_train_batch_size=None, per_gpu_eval_batch_size=None, gradient_accumulation_steps=1, eval_accumulation_steps=None, learning_rate=5e-05, weight_decay=0.0, adam_beta1=0.9, adam_beta2=0.999, adam_epsilon=1e-08, max_grad_norm=1.0, num_train_epochs=10.0, max_steps=-1, lr_scheduler_type=<SchedulerType.LINEAR: 'linear'>, warmup_ratio=0.0, warmup_steps=0, logging_dir='runs/May19_13-54-45_63c2b835e199', logging_strategy=<IntervalStrategy.STEPS: 'steps'>, logging_first_step=False, logging_steps=500, save_strategy=<IntervalStrategy.STEPS: 'steps'>, save_steps=500, save_total_limit=None, no_cuda=False, seed=42, fp16=False, fp16_opt_level='O1', fp16_backend='auto', fp16_full_eval=False, local_rank=-1, tpu_num_cores=None, tpu_metrics_debug=False, debug=[], dataloader_drop_last=False, eval_steps=500, dataloader_num_workers=0, past_index=-1, run_name='/content/drive/MyDrive/t5-small-automin-automin', disable_tqdm=False, remove_unused_columns=True, label_names=None, load_best_model_at_end=False, metric_for_best_model=None, greater_is_better=None, ignore_data_skip=False, sharded_ddp=[], deepspeed=None, label_smoothing_factor=0.0, adafactor=False, group_by_length=False, length_column_name='length', report_to=['tensorboard'], ddp_find_unused_parameters=None, dataloader_pin_memory=True, skip_memory_metrics=False, use_legacy_prediction_loop=False, push_to_hub=False, resume_from_checkpoint=None, mp_parameters='', sortish_sampler=False, predict_with_generate=True)
# 05/19/2021 13:54:45 - WARNING - datasets.builder -   Using custom data configuration default-8f2b4e3cae78ab30
# 05/19/2021 13:54:45 - WARNING - datasets.builder -   Reusing dataset csv (/root/.cache/huggingface/datasets/csv/default-8f2b4e3cae78ab30/0.0.0/2dc6629a9ff6b5697d82c25b73731dd440507a69cbce8b425db50b751e8fcfd0)
# loading configuration file https://huggingface.co/t5-small/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/fe501e8fd6425b8ec93df37767fcce78ce626e34cc5edc859c662350cf712e41.406701565c0afd9899544c1cb8b93185a76f00b31e5ce7f6e18bbaef02241985
# Model config T5Config {
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "gradient_checkpointing": false,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.7.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading configuration file https://huggingface.co/t5-small/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/fe501e8fd6425b8ec93df37767fcce78ce626e34cc5edc859c662350cf712e41.406701565c0afd9899544c1cb8b93185a76f00b31e5ce7f6e18bbaef02241985
# Model config T5Config {
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "gradient_checkpointing": false,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.7.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading file https://huggingface.co/t5-small/resolve/main/spiece.model from cache at /root/.cache/huggingface/transformers/65fc04e21f45f61430aea0c4fedffac16a4d20d78b8e6601d8d996ebefefecd2.3b69006860e7b5d0a63ffdddc01ddcd6b7c318a6f4fd793596552c741734c62d
# loading file https://huggingface.co/t5-small/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/t5-small/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/t5-small/resolve/main/tokenizer_config.json from cache at None
# loading file https://huggingface.co/t5-small/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/06779097c78e12f47ef67ecb728810c2ae757ee0a9efe9390c6419783d99382d.8627f1bd5d270a9fd2e5a51c8bec3223896587cc3cfe13edeabb0992ab43c529
# loading weights file https://huggingface.co/t5-small/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/fee5a3a0ae379232608b6eed45d2d7a0d2966b9683728838412caccc41b4b0ed.ddacdc89ec88482db20c676f0861a336f3d0409f94748c209847b49529d73885
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at t5-small.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# 100% 1/1 [00:22<00:00, 22.45s/ba]
# 100% 1/1 [00:01<00:00,  1.95s/ba]
# 100% 1/1 [00:03<00:00,  3.53s/ba]
# ***** Running training *****
#   Num examples = 85
#   Num Epochs = 10
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 220
# 100% 220/220 [01:06<00:00,  3.79it/s]
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 66.0343, 'train_samples_per_second': 3.332, 'epoch': 10.0}
# 100% 220/220 [01:06<00:00,  3.33it/s]
# Saving model checkpoint to /content/drive/MyDrive/t5-small-automin-automin
# Configuration saved in /content/drive/MyDrive/t5-small-automin-automin/config.json
# Model weights saved in /content/drive/MyDrive/t5-small-automin-automin/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/t5-small-automin-automin/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/t5-small-automin-automin/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/t5-small-automin-automin/spiece.model
# ***** train metrics *****
#   epoch                      =       10.0
#   init_mem_cpu_alloc_delta   =     1746MB
#   init_mem_cpu_peaked_delta  =        0MB
#   init_mem_gpu_alloc_delta   =      230MB
#   init_mem_gpu_peaked_delta  =        0MB
#   train_mem_cpu_alloc_delta  =       18MB
#   train_mem_cpu_peaked_delta =        0MB
#   train_mem_gpu_alloc_delta  =      692MB
#   train_mem_gpu_peaked_delta =     4318MB
#   train_runtime              = 0:01:06.03
#   train_samples              =         85
#   train_samples_per_second   =      3.332
# 05/19/2021 13:56:26 - INFO - __main__ -   *** Evaluate ***
# ***** Running Evaluation *****
#   Num examples = 10
#   Batch size = 4
# 100% 3/3 [00:05<00:00,  1.94s/it]
# ***** eval metrics *****
#   epoch                     =       10.0
#   eval_gen_len              =      121.8
#   eval_loss                 =     3.3252
#   eval_mem_cpu_alloc_delta  =        1MB
#   eval_mem_cpu_peaked_delta =        0MB
#   eval_mem_gpu_alloc_delta  =        0MB
#   eval_mem_gpu_peaked_delta =      448MB
#   eval_rouge1               =     8.8178
#   eval_rouge2               =     0.5499
#   eval_rougeL               =     7.8415
#   eval_rougeLsum            =     8.0833
#   eval_runtime              = 0:00:07.91
#   eval_samples              =         10
#   eval_samples_per_second   =      1.264
# 05/19/2021 13:56:34 - INFO - __main__ -   *** Predict ***
# ***** Running Prediction *****
#   Num examples = 18
#   Batch size = 4
# 100% 5/5 [00:08<00:00,  1.81s/it]***** predict metrics *****
#   predict_gen_len            =   120.2222
#   predict_loss               =     3.6709
#   predict_rouge1             =     8.5261
#   predict_rouge2             =     0.8303
#   predict_rougeL             =     7.1556
#   predict_rougeLsum          =     7.2031
#   predict_runtime            = 0:00:14.05
#   predict_samples            =         18
#   predict_samples_per_second =      1.281
#   test_mem_cpu_alloc_delta   =        0MB
#   test_mem_cpu_peaked_delta  =        0MB
#   test_mem_gpu_alloc_delta   =        0MB
#   test_mem_gpu_peaked_delta  =      448MB
# 100% 5/5 [00:12<00:00,  2.58s/it]

# %%
# !python examples/pytorch/summarization/run_summarization.py \
    --model_name_or_path /content/drive/MyDrive/tst-summarization-2/ \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file /content/drive/MyDrive/automin_processed/train_automin.csv \
    --validation_file /content/drive/MyDrive/automin_processed/val_automin.csv \
    --test_file /content/drive/MyDrive/automin_processed/test_automin.csv \
    --output_dir /content/drive/MyDrive/t5-small-cnn-automin \
    --learning_rate=0.001 \
    --source_prefix "summarize: " \
    --per_device_train_batch_size=4 \
    --per_device_eval_batch_size=4 \
    --num_train_epochs=10 \
    --overwrite_output_dir \
    --predict_with_generate
# Out:
# 2021-05-19 14:11:19.342380: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 05/19/2021 14:11:20 - WARNING - __main__ -   Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 05/19/2021 14:11:20 - INFO - __main__ -   Training/evaluation parameters Seq2SeqTrainingArguments(output_dir='/content/drive/MyDrive/t5-small-cnn-automin', overwrite_output_dir=True, do_train=True, do_eval=True, do_predict=True, evaluation_strategy=<IntervalStrategy.NO: 'no'>, prediction_loss_only=False, per_device_train_batch_size=4, per_device_eval_batch_size=4, per_gpu_train_batch_size=None, per_gpu_eval_batch_size=None, gradient_accumulation_steps=1, eval_accumulation_steps=None, learning_rate=0.001, weight_decay=0.0, adam_beta1=0.9, adam_beta2=0.999, adam_epsilon=1e-08, max_grad_norm=1.0, num_train_epochs=10.0, max_steps=-1, lr_scheduler_type=<SchedulerType.LINEAR: 'linear'>, warmup_ratio=0.0, warmup_steps=0, logging_dir='runs/May19_14-11-20_63c2b835e199', logging_strategy=<IntervalStrategy.STEPS: 'steps'>, logging_first_step=False, logging_steps=500, save_strategy=<IntervalStrategy.STEPS: 'steps'>, save_steps=500, save_total_limit=None, no_cuda=False, seed=42, fp16=False, fp16_opt_level='O1', fp16_backend='auto', fp16_full_eval=False, local_rank=-1, tpu_num_cores=None, tpu_metrics_debug=False, debug=[], dataloader_drop_last=False, eval_steps=500, dataloader_num_workers=0, past_index=-1, run_name='/content/drive/MyDrive/t5-small-cnn-automin', disable_tqdm=False, remove_unused_columns=True, label_names=None, load_best_model_at_end=False, metric_for_best_model=None, greater_is_better=None, ignore_data_skip=False, sharded_ddp=[], deepspeed=None, label_smoothing_factor=0.0, adafactor=False, group_by_length=False, length_column_name='length', report_to=['tensorboard'], ddp_find_unused_parameters=None, dataloader_pin_memory=True, skip_memory_metrics=False, use_legacy_prediction_loop=False, push_to_hub=False, resume_from_checkpoint=None, mp_parameters='', sortish_sampler=False, predict_with_generate=True)
# 05/19/2021 14:11:20 - WARNING - datasets.builder -   Using custom data configuration default-8f2b4e3cae78ab30
# 05/19/2021 14:11:20 - WARNING - datasets.builder -   Reusing dataset csv (/root/.cache/huggingface/datasets/csv/default-8f2b4e3cae78ab30/0.0.0/2dc6629a9ff6b5697d82c25b73731dd440507a69cbce8b425db50b751e8fcfd0)
# loading configuration file /content/drive/MyDrive/tst-summarization-2/config.json
# Model config T5Config {
#   "_name_or_path": "t5-small",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "gradient_checkpointing": false,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.7.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32100
# }
#
# loading configuration file /content/drive/MyDrive/tst-summarization-2/config.json
# Model config T5Config {
#   "_name_or_path": "t5-small",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "gradient_checkpointing": false,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.7.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32100
# }
#
# Didn't find file /content/drive/MyDrive/tst-summarization-2/added_tokens.json. We won't load it.
# Didn't find file /content/drive/MyDrive/tst-summarization-2/tokenizer.json. We won't load it.
# loading file /content/drive/MyDrive/tst-summarization-2/spiece.model
# loading file None
# loading file /content/drive/MyDrive/tst-summarization-2/special_tokens_map.json
# loading file /content/drive/MyDrive/tst-summarization-2/tokenizer_config.json
# loading file None
# loading weights file /content/drive/MyDrive/tst-summarization-2/pytorch_model.bin
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at /content/drive/MyDrive/tst-summarization-2/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# 100% 1/1 [00:22<00:00, 22.14s/ba]
# 100% 1/1 [00:01<00:00,  1.91s/ba]
# 100% 1/1 [00:03<00:00,  3.51s/ba]
# ***** Running training *****
#   Num examples = 85
#   Num Epochs = 10
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 220
# 100% 220/220 [01:06<00:00,  3.70it/s]
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 66.7041, 'train_samples_per_second': 3.298, 'epoch': 10.0}
# 100% 220/220 [01:06<00:00,  3.30it/s]
# Saving model checkpoint to /content/drive/MyDrive/t5-small-cnn-automin
# Configuration saved in /content/drive/MyDrive/t5-small-cnn-automin/config.json
# Model weights saved in /content/drive/MyDrive/t5-small-cnn-automin/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/t5-small-cnn-automin/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/t5-small-cnn-automin/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/t5-small-cnn-automin/spiece.model
# ***** train metrics *****
#   epoch                      =       10.0
#   init_mem_cpu_alloc_delta   =     1748MB
#   init_mem_cpu_peaked_delta  =        0MB
#   init_mem_gpu_alloc_delta   =      230MB
#   init_mem_gpu_peaked_delta  =        0MB
#   train_mem_cpu_alloc_delta  =       17MB
#   train_mem_cpu_peaked_delta =        0MB
#   train_mem_gpu_alloc_delta  =      692MB
#   train_mem_gpu_peaked_delta =     4318MB
#   train_runtime              = 0:01:06.70
#   train_samples              =         85
#   train_samples_per_second   =      3.298
# 05/19/2021 14:13:05 - INFO - __main__ -   *** Evaluate ***
# ***** Running Evaluation *****
#   Num examples = 10
#   Batch size = 4
# 100% 3/3 [00:06<00:00,  2.10s/it]
# ***** eval metrics *****
#   epoch                     =       10.0
#   eval_gen_len              =      123.8
#   eval_loss                 =     3.2026
#   eval_mem_cpu_alloc_delta  =        1MB
#   eval_mem_cpu_peaked_delta =        0MB
#   eval_mem_gpu_alloc_delta  =        0MB
#   eval_mem_gpu_peaked_delta =      448MB
#   eval_rouge1               =    12.9537
#   eval_rouge2               =     1.6021
#   eval_rougeL               =     9.4163
#   eval_rougeLsum            =    11.0657
#   eval_runtime              = 0:00:08.43
#   eval_samples              =         10
#   eval_samples_per_second   =      1.185
# 05/19/2021 14:13:14 - INFO - __main__ -   *** Predict ***
# ***** Running Prediction *****
#   Num examples = 18
#   Batch size = 4
# 100% 5/5 [00:08<00:00,  1.71s/it]***** predict metrics *****
#   predict_gen_len            =      125.0
#   predict_loss               =      3.659
#   predict_rouge1             =    11.0309
#   predict_rouge2             =     0.7503
#   predict_rougeL             =     9.0373
#   predict_rougeLsum          =     9.9359
#   predict_runtime            = 0:00:13.67
#   predict_samples            =         18
#   predict_samples_per_second =      1.316
#   test_mem_cpu_alloc_delta   =        0MB
#   test_mem_cpu_peaked_delta  =        0MB
#   test_mem_gpu_alloc_delta   =        0MB
#   test_mem_gpu_peaked_delta  =      448MB
# 100% 5/5 [00:12<00:00,  2.55s/it]

# %%
# !python examples/pytorch/summarization/run_summarization.py \
    --model_name_or_path /content/drive/MyDrive/tst-summarization-2/ \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file /content/drive/MyDrive/automin_processed/train_automin.csv \
    --validation_file /content/drive/MyDrive/automin_processed/val_automin.csv \
    --test_file /content/drive/MyDrive/automin_processed/test_automin.csv \
    --output_dir /content/drive/MyDrive/t5-small-cnn-automin-no-learning-rate \
    --source_prefix "summarize: " \
    --per_device_train_batch_size=4 \
    --per_device_eval_batch_size=4 \
    --num_train_epochs=10 \
    --overwrite_output_dir \
    --predict_with_generate
# Out:
# 2021-05-19 14:14:27.666216: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 05/19/2021 14:14:29 - WARNING - __main__ -   Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# 05/19/2021 14:14:29 - INFO - __main__ -   Training/evaluation parameters Seq2SeqTrainingArguments(output_dir='/content/drive/MyDrive/t5-small-cnn-automin-no-learning-rate', overwrite_output_dir=True, do_train=True, do_eval=True, do_predict=True, evaluation_strategy=<IntervalStrategy.NO: 'no'>, prediction_loss_only=False, per_device_train_batch_size=4, per_device_eval_batch_size=4, per_gpu_train_batch_size=None, per_gpu_eval_batch_size=None, gradient_accumulation_steps=1, eval_accumulation_steps=None, learning_rate=5e-05, weight_decay=0.0, adam_beta1=0.9, adam_beta2=0.999, adam_epsilon=1e-08, max_grad_norm=1.0, num_train_epochs=10.0, max_steps=-1, lr_scheduler_type=<SchedulerType.LINEAR: 'linear'>, warmup_ratio=0.0, warmup_steps=0, logging_dir='runs/May19_14-14-29_63c2b835e199', logging_strategy=<IntervalStrategy.STEPS: 'steps'>, logging_first_step=False, logging_steps=500, save_strategy=<IntervalStrategy.STEPS: 'steps'>, save_steps=500, save_total_limit=None, no_cuda=False, seed=42, fp16=False, fp16_opt_level='O1', fp16_backend='auto', fp16_full_eval=False, local_rank=-1, tpu_num_cores=None, tpu_metrics_debug=False, debug=[], dataloader_drop_last=False, eval_steps=500, dataloader_num_workers=0, past_index=-1, run_name='/content/drive/MyDrive/t5-small-cnn-automin-no-learning-rate', disable_tqdm=False, remove_unused_columns=True, label_names=None, load_best_model_at_end=False, metric_for_best_model=None, greater_is_better=None, ignore_data_skip=False, sharded_ddp=[], deepspeed=None, label_smoothing_factor=0.0, adafactor=False, group_by_length=False, length_column_name='length', report_to=['tensorboard'], ddp_find_unused_parameters=None, dataloader_pin_memory=True, skip_memory_metrics=False, use_legacy_prediction_loop=False, push_to_hub=False, resume_from_checkpoint=None, mp_parameters='', sortish_sampler=False, predict_with_generate=True)
# 05/19/2021 14:14:29 - WARNING - datasets.builder -   Using custom data configuration default-8f2b4e3cae78ab30
# 05/19/2021 14:14:29 - WARNING - datasets.builder -   Reusing dataset csv (/root/.cache/huggingface/datasets/csv/default-8f2b4e3cae78ab30/0.0.0/2dc6629a9ff6b5697d82c25b73731dd440507a69cbce8b425db50b751e8fcfd0)
# loading configuration file /content/drive/MyDrive/tst-summarization-2/config.json
# Model config T5Config {
#   "_name_or_path": "t5-small",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "gradient_checkpointing": false,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.7.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32100
# }
#
# loading configuration file /content/drive/MyDrive/tst-summarization-2/config.json
# Model config T5Config {
#   "_name_or_path": "t5-small",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "gradient_checkpointing": false,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.7.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32100
# }
#
# Didn't find file /content/drive/MyDrive/tst-summarization-2/added_tokens.json. We won't load it.
# Didn't find file /content/drive/MyDrive/tst-summarization-2/tokenizer.json. We won't load it.
# loading file /content/drive/MyDrive/tst-summarization-2/spiece.model
# loading file None
# loading file /content/drive/MyDrive/tst-summarization-2/special_tokens_map.json
# loading file /content/drive/MyDrive/tst-summarization-2/tokenizer_config.json
# loading file None
# loading weights file /content/drive/MyDrive/tst-summarization-2/pytorch_model.bin
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at /content/drive/MyDrive/tst-summarization-2/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# 100% 1/1 [00:22<00:00, 22.12s/ba]
# 100% 1/1 [00:02<00:00,  2.01s/ba]
# 100% 1/1 [00:03<00:00,  3.55s/ba]
# ***** Running training *****
#   Num examples = 85
#   Num Epochs = 10
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 220
# 100% 220/220 [01:07<00:00,  3.66it/s]
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 67.0823, 'train_samples_per_second': 3.28, 'epoch': 10.0}
# 100% 220/220 [01:07<00:00,  3.28it/s]
# Saving model checkpoint to /content/drive/MyDrive/t5-small-cnn-automin-no-learning-rate
# Configuration saved in /content/drive/MyDrive/t5-small-cnn-automin-no-learning-rate/config.json
# Model weights saved in /content/drive/MyDrive/t5-small-cnn-automin-no-learning-rate/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/t5-small-cnn-automin-no-learning-rate/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/t5-small-cnn-automin-no-learning-rate/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/t5-small-cnn-automin-no-learning-rate/spiece.model
# ***** train metrics *****
#   epoch                      =       10.0
#   init_mem_cpu_alloc_delta   =     1750MB
#   init_mem_cpu_peaked_delta  =        0MB
#   init_mem_gpu_alloc_delta   =      230MB
#   init_mem_gpu_peaked_delta  =        0MB
#   train_mem_cpu_alloc_delta  =       16MB
#   train_mem_cpu_peaked_delta =        0MB
#   train_mem_gpu_alloc_delta  =      692MB
#   train_mem_gpu_peaked_delta =     4318MB
#   train_runtime              = 0:01:07.08
#   train_samples              =         85
#   train_samples_per_second   =       3.28
# 05/19/2021 14:16:09 - INFO - __main__ -   *** Evaluate ***
# ***** Running Evaluation *****
#   Num examples = 10
#   Batch size = 4
# 100% 3/3 [00:06<00:00,  2.24s/it]
# ***** eval metrics *****
#   epoch                     =       10.0
#   eval_gen_len              =      101.7
#   eval_loss                 =     3.5551
#   eval_mem_cpu_alloc_delta  =        3MB
#   eval_mem_cpu_peaked_delta =        0MB
#   eval_mem_gpu_alloc_delta  =        0MB
#   eval_mem_gpu_peaked_delta =      448MB
#   eval_rouge1               =    14.6676
#   eval_rouge2               =     2.1649
#   eval_rougeL               =    10.3495
#   eval_rougeLsum            =    12.4769
#   eval_runtime              = 0:00:08.78
#   eval_samples              =         10
#   eval_samples_per_second   =      1.138
# 05/19/2021 14:16:19 - INFO - __main__ -   *** Predict ***
# ***** Running Prediction *****
#   Num examples = 18
#   Batch size = 4
# 100% 5/5 [00:08<00:00,  1.77s/it]***** predict metrics *****
#   predict_gen_len            =   102.7778
#   predict_loss               =     3.9026
#   predict_rouge1             =     8.4518
#   predict_rouge2             =     1.0515
#   predict_rougeL             =     6.4677
#   predict_rougeLsum          =     7.1299
#   predict_runtime            = 0:00:12.97
#   predict_samples            =         18
#   predict_samples_per_second =      1.387
#   test_mem_cpu_alloc_delta   =        0MB
#   test_mem_cpu_peaked_delta  =        0MB
#   test_mem_gpu_alloc_delta   =        0MB
#   test_mem_gpu_peaked_delta  =      448MB
# 100% 5/5 [00:12<00:00,  2.55s/it]
